# %%
import pandas as pd
import psycopg2
import config
import workdays
import datetime
import plotly
import plotly.express as px
import plotly.graph_objects as go
pd.options.mode.chained_assignment = None  # default='warn'
from matplotlib.ticker import FuncFormatter
holidays_br = workdays.load_holidays('BR')
holidays_b3 = workdays.load_holidays('B3')
from plotly_resampler import FigureResampler, EveryNthPoint, EfficientLTTB
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from functools import reduce

# %%
db_conn_k11 = psycopg2.connect(host=config.DB_K11_HOST, dbname=config.DB_K11_NAME , user=config.DB_K11_USER, password=config.DB_K11_PASS)
query=f"SELECT ticker, spread_bps, spread_localccy, spread_usd, data_hora FROM public.adr_spread  where data_hora>'2022-07-15'"


df =pd.read_sql(query,db_conn_k11)
db_conn_k11.close()

# %%
df=df.drop_duplicates()

# %%
tickers = dict()

# %%
# papeis = df['ticker'].unique()
# papeis=['PETR3','ABEV3','PETR4','BBDC4']

# %%
papeis=['BRFS3','PCAR3','ABEV3']

# %%
papeis
# Out:
# ['BRFS3', 'PCAR3', 'ABEV3']

# %%
aux = aux[np.abs(aux['spread_bps']-aux['spread_bps'].mean()) <= (3*aux['spread_bps'].std())]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JOAO~1.RAM\AppData\Local\Temp/ipykernel_21604/2269246025.py in <module>
# ----> 1 aux = aux[np.abs(aux['spread_bps']-aux['spread_bps'].mean()) <= (3*aux['spread_bps'].std())]
#
# NameError: name 'np' is not defined

# %%
tickers['PETR4'][np.abs(tickers['PETR4']['PETR4']-tickers['PETR4']['PETR4'].mean()) <= (3*tickers['PETR4']['PETR4'].std())].sort_values('data_hora').plot()
# Out:
# <AxesSubplot:xlabel='data_hora'>

# %%
aux = tickers['PETR4'][np.abs(tickers['PETR4']['PETR4']-tickers['PETR4']['PETR4'].mean()) <= (3*tickers['PETR4']['PETR4'].std())].sort_values('data_hora')

# %%
entrada = {
'ABEV3':-127.53627175215499,
'BRFS3':-117.56452607569001,
'PCAR3':-98.62502378144538
    }

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i,t in enumerate(papeis):
#     print(t)
    tickers.__setitem__(f"{t}",df[df['ticker']==f"{t}"].sort_values(by='data_hora',ascending=True).rename(columns={'spread_bps':f"{t}"}))
    tickers[t]['data_hora'] = tickers[t]['data_hora'].astype(str)
    tickers[t]=tickers[t][['data_hora',f"{t}"]].set_index('data_hora')
    tickers[t] = tickers[t][np.abs(tickers[t][t]-tickers[t][t].mean()) <= (3*tickers[t][t].std())].sort_values('data_hora').dropna()
    tickers[t] = tickers[t][np.abs(tickers[t][t]-tickers[t][t].mean()) <= (3*tickers[t][t].std())].sort_values('data_hora').dropna()
    
    tickers[t][f"{t}_mma"]=tickers[t][t].rolling(200).mean()
#     display(tickers[t][f"{t}_mma"].iloc[-5:])
    mininimo = tickers[t][f"{t}_mma"].min()
    maximo = tickers[t][f"{t}_mma"].max()
#     display(f"{t} min: {mininimo}" ) 
#     display(f"{t} max: {maximo}" ) 
    
    
    tickers[t].plot(kind='line',title=f"{t}",figsize=(16,8))
    plt.axhline(y=entrada[t], color='r', linestyle='-')
    plt.axhline(y=entrada[t]-26, color='g', linestyle='-')
#     print(tickers[t].min())
    
#     tickers[t].plot(kind='line',title=f"{t}")
    
# 
#     tickers[t].sort_values(by='data_hora',ascending=True)   
    
    
#     tickers[t]['data_hora']=[x for x in range(len(tickers[t][f"{t}"])) ]
    if i==0:
              
        complete=tickers[t][[f"{t}_mma"]]
    else:
        complete = complete.merge(tickers[t][[f"{t}_mma"]],on='data_hora',how='left')

# %%
aux = complete[['ABEV3_mma','AZUL4_mma']].fillna(0)

aux[(aux['ABEV3_mma']!=0) & (aux['AZUL4_mma']==0) ]

# %%
for i,t in enumerate(papeis):
    print(t)
    complete[f"{t}_avg"]=complete[t].rolling(12000).mean()

# %%
complete = complete.dropna()

# %%
complete

# %%
complete=complete.set_index('data_hora')

# %%
2*complete.BBDC4_avg.std()

# %%
complete=complete[['PETR3_mma','ABEV3_mma','PETR4_mma','BBDC4_mma']].dropna()

# %%
import numpy as np

# %%
complete = complete[np.abs(complete.BBDC4_avg-complete.BBDC4_avg.mean()) <= (2*complete.BBDC4_avg.std())]

# %%
complete['ABEV3_avg'].plot(kind='line')

# %%
# # # for f,value in tickers.items():
# fig = px.line(complete,x=complete.index.tolist(),y=complete.columns.tolist())
# fig.update_layout(xaxis={'type': 'category'})
# fig.show()
type(complete.index[0])

# %%
aux = complete.fillna(0)

# %%
fig = px.line(aux)
fig.show()
